# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter

# %%
data = pd.read_csv('movie_bd_v5.csv')
data.sample(5)

# %%
data.describe()

# %% [markdown]
# # Предобработка

# %%
answers = {} # создадим словарь для ответов

data['profit']=data['revenue']-data['budget']

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?

# %% [markdown]
# Использовать варианты ответов в коде решения запрещено.
# Вы думаете и в жизни у вас будут варианты ответов?)

# %%
answers['1'] = '5.Pirates of the Caribbean: On Stranger Tides (tt1298650)'

# %%
# тут пишем ваш код для решения данного вопроса:
import pandas as pd
data_1 = pd.read_csv('movie_bd_v5.xls')
# сортируем бюджет по возрастанию
data_1 = data_1.sort_values('budget', ascending=False)
# 5 верхних вариантов
data_1.head()
# Out:
#         imdb_id     budget     revenue  \
# 723   tt1298650  380000000  1021683000
# 1669  tt0449088  300000000   961000000
# 14    tt2395427  280000000  1405035767
# 1014  tt0401729  260000000   284139100
# 380   tt0398286  260000000   591794936
#
#                                    original_title  \
# 723   Pirates of the Caribbean: On Stranger Tides
# 1669     Pirates of the Caribbean: At World's End
# 14                        Avengers: Age of Ultron
# 1014                                  John Carter
# 380                                       Tangled
#
#                                                    cast  \
# 723   Johnny Depp|PenÃ©lope Cruz|Geoffrey Rush|Ian M...
# 1669  Johnny Depp|Orlando Bloom|Keira Knightley|Geof...
# 14    Robert Downey Jr.|Chris Hemsworth|Mark Ruffalo...
# 1014  Taylor Kitsch|Lynn Collins|Mark Strong|Willem ...
# 380   Zachary Levi|Mandy Moore|Donna Murphy|Ron Perl...
#
#                        director  \
# 723                Rob Marshall
# ...

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)?

# %%
answers['2'] = '2.Gods and Generals (tt0279111)'

# %%
import pandas as pd
data_2 = pd.read_csv('movie_bd_v5.xls')
# сортируем время по возрастанию
data_2 = data_2.sort_values('runtime', ascending=False)
# 5 верхних вариантов
data_2.head()
# Out:
#         imdb_id     budget     revenue  \
# 1157  tt0279111   56000000    12923936
# 1081  tt0167260   94000000  1118888979
# 1736  tt0462322   67000000    25037897
# 1336  tt0360717  207000000   550000000
# 504   tt0213149  140000000   449220945
#
#                                      original_title  \
# 1157                              Gods and Generals
# 1081  The Lord of the Rings: The Return of the King
# 1736                                     Grindhouse
# 1336                                      King Kong
# 504                                    Pearl Harbor
#
#                                                    cast  \
# 1157  Stephen Lang|Jeff Daniels|Robert Duvall|Kevin ...
# 1081  Elijah Wood|Ian McKellen|Viggo Mortensen|Liv T...
# 1736  Kurt Russell|ZoÃ« Bell|Rosario Dawson|Vanessa ...
# 1336  Naomi Watts|Jack Black|Adrien Brody|Thomas Kre...
# 504   Ben Affleck|Josh Hartnett|Kate Beckinsale|Cuba...
#
#                                                director  \
# ...

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)?

# %%
answers['3'] = '3.Winnie the Pooh (tt1449283)'

# %%
import pandas as pd
data_3 = pd.read_csv('movie_bd_v5.xls')
# сортируем время по возрастанию
data_3 = data_3.sort_values('runtime', ascending=False)
# 5 нижних результатов
data_3.tail()
# Out:
#         imdb_id     budget    revenue        original_title  \
# 1408  tt0361089   35000000   19478106               Valiant
# 1626  tt0299172  110000000  103951461     Home on the Range
# 1097  tt0283426   20000000  135680000     The Jungle Book 2
# 930   tt0280030   20000000  109862682  Return to Never Land
# 768   tt1449283   30000000   14460000       Winnie the Pooh
#
#                                                    cast  \
# 1408  Ewan McGregor|Ricky Gervais|Tim Curry|Jim Broa...
# 1626  Randy Quaid|Steve Buscemi|Judi Dench|Cuba Good...
# 1097  John Goodman|Haley Joel Osment|Mae Whitman|Phi...
# 930   Harriet Owen|Blayne Weaver|Jeff Bennett|Kath S...
# 768   Jim Cummings|Travis Oates|Jim Cummings|Bud Luc...
#
#                        director  \
# 1408               Gary Chapman
# 1626     Will Finn|John Sanford
# 1097            Steve Trenbirth
# 930     Robin Budd|Donovan Cook
# 768   Stephen Anderson|Don Hall
#
#                                             tagline  \
# ...

# %% [markdown]
# # 4. Какова средняя длительность фильмов?

# %%
answers['4'] = '2.110'

# %%
import pandas as pd
data_4 = pd.read_csv('movie_bd_v5.xls')
# выводим описание датафрейма
data_4.describe()
# Out:
#              budget       revenue      runtime  vote_average  release_year
# count  1.889000e+03  1.889000e+03  1889.000000   1889.000000   1889.000000
# mean   5.431083e+07  1.553653e+08   109.658549      6.140762   2007.860773
# std    4.858721e+07  2.146698e+08    18.017041      0.764763      4.468841
# min    5.000000e+06  2.033165e+06    63.000000      3.300000   2000.000000
# 25%    2.000000e+07  3.456058e+07    97.000000      5.600000   2004.000000
# 50%    3.800000e+07  8.361541e+07   107.000000      6.100000   2008.000000
# 75%    7.200000e+07  1.782626e+08   120.000000      6.600000   2012.000000
# max    3.800000e+08  2.781506e+09   214.000000      8.100000   2015.000000

# %% [markdown]
# # 5. Каково медианное значение длительности фильмов?

# %%
answers['5'] = '1.107'

# %%
import pandas as pd
data_6 = pd.read_csv('movie_bd_v5.xls')
# добавляем столбец "profit"
data_6['profit']=data_6['revenue']-data_6['budget']

# %% [markdown]
# # 6. Какой самый прибыльный фильм?
# #### Внимание! Здесь и далее под «прибылью» или «убытками» понимается разность между сборами и бюджетом фильма. (прибыль = сборы - бюджет) в нашем датасете это будет (profit = revenue - budget)

# %%
answers['6'] = '5.Avatar (tt0499549)'

# %%
import pandas as pd
data_6 = pd.read_csv('movie_bd_v5.xls')
# добавляем столбец "profit"
data_6['profit']=data_6['revenue']-data_6['budget']
# сортируем по возрастанию прибыли
data_6 = data_6.sort_values('profit', ascending=False)
# выводим 5 верхних строк
data_6.head()
# Out:
#        imdb_id     budget     revenue                original_title  \
# 239  tt0499549  237000000  2781505847                        Avatar
# 3    tt2488496  200000000  2068178225  Star Wars: The Force Awakens
# 0    tt0369610  150000000  1513528810                Jurassic World
# 4    tt2820852  190000000  1506249360                     Furious 7
# 970  tt0848228  220000000  1519557910                  The Avengers
#
#                                                   cast         director  \
# 239  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...    James Cameron
# 3    Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...      J.J. Abrams
# 0    Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
# 4    Vin Diesel|Paul Walker|Jason Statham|Michelle ...        James Wan
# 970  Robert Downey Jr.|Chris Evans|Mark Ruffalo|Chr...      Joss Whedon
#
#                            tagline  \
# 239    Enter the World of Pandora.
# 3    Every generation has a story.
# ...

# %% [markdown]
# # 7. Какой фильм самый убыточный?

# %%
answers['7'] = '5.The Lone Ranger (tt1210819)'

# %%
import pandas as pd
data_7 = pd.read_csv('movie_bd_v5.xls')
data_7['profit']=data_7['revenue']-data_7['budget']
# сортируем по возрастанию прибыли
data_7 = data_7.sort_values('profit', ascending=False)
# выводим 5 последних строк
data_7.tail()
# Out:
#         imdb_id     budget   revenue                original_title  \
# 1464  tt0424095  149000000  64459316                  Flushed Away
# 958   tt0180052  100000000   7103973  The Adventures of Pluto Nash
# 809   tt1305591  150000000  38992758               Mars Needs Moms
# 1616  tt0318974  145000000  25819961                     The Alamo
# 1245  tt1210819  255000000  89289910               The Lone Ranger
#
#                                                    cast  \
# 1464  Hugh Jackman|Kate Winslet|Ian McKellen|Jean Re...
# 958   Eddie Murphy|Randy Quaid|Rosario Dawson|Joe Pa...
# 809   Seth Green|Joan Cusack|Dan Fogler|Breckin Meye...
# 1616  Dennis Quaid|Billy Bob Thornton|Jason Patric|P...
# 1245  Johnny Depp|Armie Hammer|William Fichtner|Hele...
#
#                    director                         tagline  \
# 1464  David Bowers|Sam Fell            Someone's Going Down
# 958           Ron Underwood  Action's future has arrived...
# ...

# %% [markdown]
# # 8. У скольких фильмов из датасета объем сборов оказался выше бюджета?

# %%
answers['8'] = '1.1478'

# %%
import pandas as pd
data_8 = pd.read_csv('movie_bd_v5.xls')
# отбираем фильмы со сбором больше бюджета
data_8 = data_8[data_8.revenue > data_8.budget]
# выводим таблицу
display (data_8)
# Out:
#         imdb_id     budget     revenue                original_title  \
# 0     tt0369610  150000000  1513528810                Jurassic World
# 1     tt1392190  150000000   378436354            Mad Max: Fury Road
# 2     tt2908446  110000000   295238201                     Insurgent
# 3     tt2488496  200000000  2068178225  Star Wars: The Force Awakens
# 4     tt2820852  190000000  1506249360                     Furious 7
# ...         ...        ...         ...                           ...
# 1871  tt0171433   30000000    37036004             Keeping the Faith
# 1875  tt0219854   65000000    69700000                       The Kid
# 1877  tt0199725   20000000    27728118             Love & Basketball
# 1883  tt0122459   24000000    36609995                  Return to Me
# 1884  tt0120903   75000000   157299717                         X-Men
#
#                                                    cast  \
# 0     Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# ...

# %% [markdown]
# # 9. Какой фильм оказался самым кассовым в 2008 году?

# %%
answers['9'] = '4.The Dark Knight (tt0468569)'

# %%
import pandas as pd
data_9 = pd.read_csv('movie_bd_v5.xls')
data_9['profit']=data_9['revenue']-data_9['budget']
# выделяем фильмы 2008 года и сортируем по прибыли
data_9 = data_9.loc[(data_9['release_year']== 2008)].sort_values(by='profit')
# выводим таблицу
display (data_9)

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 г. (включительно)?

# %%
answers['10'] = '5.The Lone Ranger (tt1210819)'

# %%
import pandas as pd
data_10 = pd.read_csv('movie_bd_v5.xls')
data_10['profit']=data_10['revenue']-data_10['budget']
# выбираем фильмы между 2012 и 2014 годами и сортируем по прибыли
data_10 = data_10.loc[(data_10['release_year']<= 2014) &(data_10['release_year']>=2012)].sort_values(by='profit')
# выводим таблицу
display (data_10)
# Out:
#         imdb_id     budget     revenue                   original_title  \
# 1245  tt1210819  255000000    89289910                  The Lone Ranger
# 1214  tt0790736  130000000    61648500                         R.I.P.D.
# 1007  tt1374992   60000000     8106475                      Upside Down
# 1302  tt0884726   70000000    18662027  Legends of Oz: Dorothy's Return
# 1235  tt1308729   55000000     9489829               Bullet to the Head
# ...         ...        ...         ...                              ...
# 1189  tt1690953   76000000   970761885                  Despicable Me 2
# 974   tt1074638  200000000  1108561013                          Skyfall
# 1180  tt1300854  200000000  1215439994                       Iron Man 3
# 1177  tt2294629  150000000  1274219009                           Frozen
# 970   tt0848228  220000000  1519557910                     The Avengers
#
#                                                    cast  \
# ...

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?

# %%
answers['11'] = '3.Drama'

# %%
import pandas as pd
data_11 = pd.read_csv('movie_bd_v5.xls')
# разделяем жанры и считаем количество
data_11 =  pd.Series(data_11['genres'].str.cat(sep='|').split('|')).value_counts()
# выводим таблицу
display(data_11)

# %%
# вариант 2
data_11.index[0]

# %% [markdown]
# # 12. Фильмы какого жанра чаще всего становятся прибыльными?

# %%
answers['12'] = '1.Drama'

# %%
import pandas as pd
data_12 = pd.read_csv('movie_bd_v5.xls')
# разделяем жанры
data_12['genres'] = data_12['genres'].apply(lambda x:x.split('|'))
def genres_count(a):
    for i in a:
        if i in genres_dict:
            genres_dict[i] += 1
        else:
            genres_dict[i] = 1
    return genres_dict

genres_dict = {}

data_12['genres'].apply(genres_count)

genres_series = pd.Series(genres_dict).sort_values(ascending=False)
# выводим таблицу
display(genres_series)
# Out:
# Drama              782
# Comedy             683
# Thriller           596
# Action             582
# Adventure          415
# Crime              315
# Romance            308
# Family             260
# Science Fiction    248
# Fantasy            222
# Horror             176
# Mystery            168
# Animation          139
# Music               64
# History             62
# War                 58
# Western             19
# Documentary          8
# Foreign              2
# dtype: int64

# %% [markdown]
# # 13. У какого режиссера самые большие суммарные кассовые сбооры?

# %%
answers['13'] = '5.Peter Jackson'

# %%
import pandas as pd
data_13 = pd.read_csv('movie_bd_v5.xls')
# разделяем режиссёров
data_13['director'] = data_13['director'].apply(lambda x:x.split('|'))
data_director=data_13.explode('director')
# суммируем кассовые сборы и сортируем по величине
data_director.groupby(['director'])['revenue'].sum().sort_values(ascending = False)
# Out:
# director
# Peter Jackson        6490593685
# Christopher Nolan    4167548502
# David Yates          4154295625
# Michael Bay          3886938960
# J.J. Abrams          3579169916
#                         ...
# David MichÃ´d           2295423
# Steven Shainberg        2281089
# Paul Schrader           2062066
# Keanu Reeves            2054941
# Simon Hunter            2033165
# Name: revenue, Length: 997, dtype: int64

# %% [markdown]
# # 14. Какой режисер снял больше всего фильмов в стиле Action?

# %%
answers['14'] = '3.Robert Rodriguez'

# %%
import pandas as pd
from collections import Counter

data_14 = pd.read_csv('movie_bd_v5.xls')

# выделяем строки, в которых содержится Action
data_14 = data_14[data_14.genres.str.contains('Action', na = False)]
# считаем, у какого режиссёра таких значений больше
collections.Counter(data_14['director'].str.cat(sep = '|').split('|')).most_common(1)

# %% [markdown]
# # 15. Фильмы с каким актером принесли самые высокие кассовые сборы в 2012 году?

# %%
answers['15'] = '3.Chris Hemsworth'

# %%
data_15 = pd.read_csv('movie_bd_v5.xls')
# разделяем актёров
data_15['cast'] = data_15['cast'].apply(lambda x:x.split('|'))
# выбираем 2012
data_15 = data_15[data_15['release_year'] == 2012]
data_cast=data_15.explode('cast')
# сортируем по самым высоким кассовым сборам
data_cast.groupby(['cast'])['revenue'].sum().sort_values(ascending = False)
# Out:
# cast
# Chris Hemsworth      2027450773
# Denis Leary          1629460639
# Anne Hathaway        1522851057
# Chris Evans          1519557910
# Robert Downey Jr.    1519557910
#                         ...
# Jason Bateman           3428048
# Danny Huston            2106557
# Sami Gayle              2106557
# Josh Lucas              2106557
# Nicolas Cage            2106557
# Name: revenue, Length: 466, dtype: int64

# %% [markdown]
# # 16. Какой актер снялся в большем количестве высокобюджетных фильмов?

# %%
answers['16'] = '3.Matt Damon'

# %%
data_16=pd.read_csv('movie_bd_v5.xls')
# разделяем актёров
data_16['cast'] = data_16['cast'].apply(lambda x: x.split('|'))
data_director=data.explode('cast')
# выделяем актёров с бюджетом выше среднего
data_director.loc[data_director['budget']> data_director['budget'].mean()]['cast'].value_counts(ascending=False)

# %% [markdown]
# # 17. В фильмах какого жанра больше всего снимался Nicolas Cage?

# %%
answers['17'] = '2.Action'

# %%
data_17=pd.read_csv('movie_bd_v5.xls')
# выделяем строки с Николасов Кеёджем
answers_17=data_17[data_17.cast.str.contains('Nicolas Cage')]
# Выделяем наиболее часто встречающийся жанр
Counter(answers_17.genres.str.split('|').sum()).most_common(1)
# Out:
# [('Action', 17)]

# %% [markdown]
# # 18. Самый убыточный фильм от Paramount Pictures

# %%
answers['18'] = '1.K-19: The Widowmaker (tt0267626)'

# %%
data_18=pd.read_csv('movie_bd_v5.xls')
data_18['profit']=data_18['revenue']-data_18['budget']
# выделяем строки, содержащие Парамаунт Пикчерз
data_pp = data_18[data_18.production_companies.str.contains('Paramount Pictures')]
# сортируем по прибыли
data_18 = data_pp.sort_values('profit', ascending=False)
# выводим 5 последних строк
data_18.tail()
# Out:
#         imdb_id     budget   revenue        original_title  \
# 1631  tt0315297   50000000  25195000               Twisted
# 1623  tt0375173   60000000  13395939                 Alfie
# 1722  tt0435705   70000000  18211013                  Next
# 1123  tt0300556   80000000  19480739              Timeline
# 925   tt0267626  100000000  35168966  K-19: The Widowmaker
#
#                                                    cast         director  \
# 1631  Ashley Judd|Samuel L. Jackson|Andy GarcÃ­a|Dav...   Philip Kaufman
# 1623  Jude Law|Marisa Tomei|Omar Epps|Jane Krakowski...    Charles Shyer
# 1722  Nicolas Cage|Julianne Moore|Jessica Biel|Thoma...     Lee Tamahori
# 1123  Paul Walker|Frances O'Connor|Gerard Butler|Bil...   Richard Donner
# 925   Harrison Ford|Liam Neeson|Peter Sarsgaard|Joss...  Kathryn Bigelow
#
#                                                 tagline  \
# 1631                           Every murder has a mark.
# ...

# %% [markdown]
# # 19. Какой год стал самым успешным по суммарным кассовым сборам?

# %%
answers['19'] = '3.2012'

# %%
data = pd.read_csv('movie_bd_v5.xls')
data_release_year.groupby(['release_year'])['revenue'].sum().sort_values(ascending = False)

# %% [markdown]
# # 20. Какой самый прибыльный год для студии Warner Bros?

# %%
answers['20'] = '1.2014'

# %%
data_20 = pd.read_csv('movie_bd_v5.xls')
data_20['profit']=data_20['revenue']-data_20['budget']
# выделяем строки, содержащие Ворнер Броз.
data_wb = data_20[data_20.production_companies.str.contains('Warner Bros')]
# группируем по году и сумме прибыли, сортируем по увеличению
data_wb.groupby(['release_year'])['profit'].sum().sort_values(ascending = False)
# Out:
# release_year
# 2014    2295464519
# 2007    2201675217
# 2008    2134595031
# 2010    1974712985
# 2011    1871393682
# 2003    1855493377
# 2009    1822454136
# 2013    1636453400
# 2004    1631933725
# 2005    1551980298
# 2001    1343545668
# 2012    1258020056
# 2002    1022709901
# 2015     870368348
# 2006     620170743
# 2000     452631386
# Name: profit, dtype: int64

# %% [markdown]
# # 21. В каком месяце за все годы суммарно вышло больше всего фильмов?

# %%
answers['21'] = '5.Сентябрь'

# %%
data_21=pd.read_csv('movie_bd_v5.xls')
# разделяем даты релиза
data_21.release_date = data_21.release_date.apply(lambda x: x.split('/'))
# выделяем месяц в отдельный столбец
data_21['month']=data_21['release_date'].apply(lambda x: x[0])
# сортируем столбец месяц
data_21['month'].value_counts()
# Out:
# 9     227
# 12    190
# 10    186
# 8     161
# 3     156
# 4     149
# 6     147
# 11    146
# 7     142
# 5     140
# 2     135
# 1     110
# Name: month, dtype: int64

# %% [markdown]
# # 22. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)

# %%
answers['22'] = '2.450'

# %%
data_22=pd.read_csv('movie_bd_v5.xls')
# разделяем даты релиза
data_22.release_date = data_22.release_date.apply(lambda x: x.split('/'))
# выделяем месяц в отдельный столбец
data_22['month']=data_22['release_date'].apply(lambda x: x[0])
# свожу в таблицу летние месяцы
pivot = data_22.loc[data_22['month'].isin(['6','7','8'])]
# вывожу таблицу
display(pivot)

# %% [markdown]
# # 23. Для какого режиссера зима – самое продуктивное время года?

# %%
answers['23'] = '1.Steven Soderbergh'

# %%
data_23 = pd.read_csv('movie_bd_v5.xls')
# разделяю режиссёров
data_23['director'] = data_23['director'].apply(lambda x:x.split('|'))
# разделяю даты релизов
data_23.release_date = data_23.release_date.apply(lambda x: x.split('/'))
# выделяю месяц
data_23['month']=data_23['release_date'].apply(lambda x: x[0])
# объединяю замние месяцы
pivot = data_23.loc[data_23['month'].isin(['12','1','2'])]
# вывожу в порядке возрастания
pivot['director'].value_counts()
# Out:
# [Peter Jackson]                       7
# [Clint Eastwood]                      6
# [Steven Soderbergh]                   6
# [Shawn Levy]                          4
# [Nancy Meyers]                        4
#                                      ..
# [Paul Tibbitt]                        1
# [Florian Henckel von Donnersmarck]    1
# [Niki Caro]                           1
# [Mikael HÃ¥fstrÃ¶m]                   1
# [Guy Ferland]                         1
# Name: director, Length: 332, dtype: int64

# %% [markdown]
# # 24. Какая студия дает самые длинные названия своим фильмам по количеству символов?

# %%
answers['24'] = '5.Four By Two Productions'

# %%
data_24=pd.read_csv('movie_bd_v5.xls')
data_24['name_length'] = data_24.original_title.apply(lambda x: len(x))
data_24['production_companies_list'] = data_24.production_companies.str.split("|")
production_companies_df = data_24.explode('production_companies_list')
answers24 = production_companies_df.groupby('production_companies_list').name_length.mean().sort_values(ascending=False).index[0]
print(answers24)
# Out:
# Four By Two Productions

# %% [markdown]
# # 25. Описание фильмов какой студии в среднем самые длинные по количеству слов?

# %%
answers['25'] = '1.Universal Pictures'

# %%
data_25=pd.read_csv('movie_bd_v5.xls')
data_25['production_companies']=data_25['production_companies'].apply(lambda x:x.split("|"))
data_pc25=data_25.explode('production_companies')
data_pc25['wordsnumber']=data_pc25['overview'].str.split().apply(len)
data_pc25 = data_pc25.sort_values('wordsnumber', ascending=False)
data_pc25.head()
# Out:
#        imdb_id     budget    revenue           original_title  \
# 711  tt0805570   15000000    3533227  The Midnight Meat Train
# 711  tt0805570   15000000    3533227  The Midnight Meat Train
# 711  tt0805570   15000000    3533227  The Midnight Meat Train
# 711  tt0805570   15000000    3533227  The Midnight Meat Train
# 170  tt1267297  100000000  243400000                 Hercules
#
#                                                   cast          director  \
# 711  Bradley Cooper|Vinnie Jones|Brooke Shields|Les...  RyÃ»hei Kitamura
# 711  Bradley Cooper|Vinnie Jones|Brooke Shields|Les...  RyÃ»hei Kitamura
# 711  Bradley Cooper|Vinnie Jones|Brooke Shields|Les...  RyÃ»hei Kitamura
# 711  Bradley Cooper|Vinnie Jones|Brooke Shields|Les...  RyÃ»hei Kitamura
# 170  Dwayne Johnson|Ian McShane|John Hurt|Rufus Sew...      Brett Ratner
#
#                                        tagline  \
# 711  The most terrifying ride you'll ever take
# 711  The most terrifying ride you'll ever take
# ...

# %% [markdown]
# # 26. Какие фильмы входят в 1 процент лучших по рейтингу?
# по vote_average

# %%
answers['26'] = '1.Inside Out, The Dark Knight, 12 Years a Slave'

# %%
data_26 = data.sort_values('vote_average')[['original_title', 'vote_average']]
data_26.query('vote_average >= vote_average.quantile(0.99)').\
    sort_values('vote_average', ascending=False).\
    head(10)
# Out:
#                                      original_title  vote_average
# 599                                 The Dark Knight           8.1
# 125                              The Imitation Game           8.0
# 9                                        Inside Out           8.0
# 118                                    Interstellar           8.0
# 34                                             Room           8.0
# 872                                     The Pianist           7.9
# 1081  The Lord of the Rings: The Return of the King           7.9
# 138                        The Grand Budapest Hotel           7.9
# 1183                        The Wolf of Wall Street           7.9
# 370                                       Inception           7.9

# %% [markdown]
# # 27. Какие актеры чаще всего снимаются в одном фильме вместе?

# %% [markdown]
# answers['27'] = '5.Daniel Radcliffe & Rupert Grint'

# %%
data_27=pd.read_csv('movie_bd_v5.xls')
data_27['cast']=data_27['cast'].apply(lambda x: x.split('|'))
from itertools import combinations
data_27['pairs'] = data_27['cast'].apply(lambda s: list(combinations(s, 2)))
display(data_27)
# Out:
#         imdb_id     budget     revenue                        original_title  \
# 0     tt0369610  150000000  1513528810                        Jurassic World
# 1     tt1392190  150000000   378436354                    Mad Max: Fury Road
# 2     tt2908446  110000000   295238201                             Insurgent
# 3     tt2488496  200000000  2068178225          Star Wars: The Force Awakens
# 4     tt2820852  190000000  1506249360                             Furious 7
# ...         ...        ...         ...                                   ...
# 1884  tt0120903   75000000   157299717                                 X-Men
# 1885  tt0192255   22000000    13555988                    The Little Vampire
# 1886  tt0131704   76000000    35134820  The Adventures of Rocky & Bullwinkle
# 1887  tt0162983   40000000    36037909                            Hanging Up
# 1888  tt0163676   15000000     5217498                          The In Crowd
#
# ...

# %% [markdown]
# # Submission
